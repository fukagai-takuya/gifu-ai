# %% [markdown]
# <a href="https://colab.research.google.com/github/fukagai-takuya/gifu-ai/blob/main/gifu-ai-2026-03-15/FLUX2_klein_4B_check_network_architecture.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. 勉強会用に fork した diffusers のリポジトリを git clone し、ディレクトリを diffusers に変えてから、調査用に用意したブランチ investigate_flux.2_klein_4B にブランチを変えます。このブランチには調査用のブレイクポイントが `Flux2KleinPipeline.__call__` の  Denoising loop の前にセットされています。

# %%
# !git clone https://github.com/huggingface/diffusers
# %cd diffusers
# Out:
# Cloning into 'diffusers'...
# remote: Enumerating objects: 117069, done.
# remote: Counting objects: 100% (1014/1014), done.
# remote: Compressing objects: 100% (567/567), done.
# remote: Total 117069 (delta 707), reused 447 (delta 447), pack-reused 116055 (from 4)
# Receiving objects: 100% (117069/117069), 91.77 MiB | 13.41 MiB/s, done.
# Resolving deltas: 100% (87191/87191), done.
# /content/diffusers

# %% [markdown]
# 2. git clone した diffusers のソースコードを優先して参照するようにします

# %%
import sys
sys.path.insert(0, "/content/diffusers/src")

# %% [markdown]
# 3. git clone した diffusers のソースコードが優先して参照されることを確認します

# %%
import diffusers
print(diffusers.__file__)
# Out:
# /content/diffusers/src/diffusers/__init__.py

# %% [markdown]
# 4. diffusers を使用して FLUX.2 [klein] 4B を実行する際に必要なパッケージをインストールします

# %%
# !pip install torch torchvision torchaudio
# !pip install transformers accelerate safetensors
# !pip install sentencepiece protobuf einops

# %% [markdown]
# 5. FLUX.2 [klein] 4B を使用した Pipeline を用意します

# %%
from diffusers import FluxPipeline
import torch

pipe = FluxPipeline.from_pretrained(
    "black-forest-labs/FLUX.2-klein-4B",
    torch_dtype=torch.float32,  # CPUはfloat32が安定
    device_map="cpu"
)
# Out:
# WARNING:torchao.kernel.intmm:Warning: Detected no triton, on systems without Triton certain kernels will not work
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# model_index.json:   0%|          | 0.00/446 [00:00<?, ?B/s]
# ...
# Loading weights:   0%|          | 0/398 [00:00<?, ?it/s]

# %% [markdown]
# 6. print 文で FLUX.2 [klein] 4B の構成を調べます

# %%
print("pipe")
print(pipe)
print("pipe.components.keys()")
print(pipe.components.keys())
print("pipe.transformer")
print(pipe.transformer)
