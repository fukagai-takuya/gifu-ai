# %% [markdown]
# <a href="https://colab.research.google.com/github/fukagai-takuya/gifu-ai/blob/main/gifu-ai-2025-12-21/StableDiffusion_3_5_Medium.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U diffusers transformers accelerate protobuf sentencepiece

import torch
from diffusers import StableDiffusion3Pipeline
from huggingface_hub import login

login()

# 重要：low_cpu_mem_usage と use_safetensors を有効にしてモデルを読み込む
pipe = StableDiffusion3Pipeline.from_pretrained(
    "stabilityai/stable-diffusion-3.5-medium",
    torch_dtype=torch.float16,
    use_safetensors=True,
    low_cpu_mem_usage=True,
)

# メモリ節約設定
pipe.enable_attention_slicing()
pipe.vae.to(torch.float16)

# GPU に必要な部分だけ載せる
pipe.to("cuda")

prompt = "A blue bird holding a sign that says 'Gifu AI Study Group'"

image = pipe(
    prompt,
    num_inference_steps=30,
    guidance_scale=7.0,
).images[0]

image.save("blue-bird-with-sign.png")
image

# %%
# !nvidia-smi

# %%
prompt = "An image of the text 'Gifu AI Study Group' created by arranging leaves."

image = pipe(
    prompt,
    num_inference_steps=30,
    guidance_scale=7.0,
).images[0]

image.save("Leaves-v1.png")
image

# %%
prompt = "An image of the text '岐阜AI勉強会' created by arranging leaves."

image = pipe(
    prompt,
    num_inference_steps=30,
    guidance_scale=7.0,
).images[0]

image.save("Leaves-Japanese-v1.png")
image

# %%
prompt = "The Japanese text '岐阜AI勉強会' formed using arranged leaves, top-down view, highly detailed, realistic leaves, natural colors, centered text, clear and readable, artistic, photorealistic, 8k"

image = pipe(
    prompt,
    num_inference_steps=30,
    guidance_scale=7.0,
).images[0]

image.save("Leaves-Japanese-v2.png")
image

# %%
prompt = "The English text 'Gifu AI Study Group' formed using arranged autumn leaves"

image = pipe(
    prompt,
    num_inference_steps=30,
    guidance_scale=7.0,
).images[0]

image.save("Leaves-v2.png")
image

# %%
prompt = "An image of the text 'Gifu AI Study Group' created by arranging autumn leaves."

image = pipe(
    prompt,
    num_inference_steps=30,
    guidance_scale=7.0,
).images[0]

image.save("Leaves-v3.png")
image

# %%
prompt = "An image of the text 'Gifu AI Study Group' created by arranging autumn leaves. The letters themselves are written with leaves."

image = pipe(
    prompt,
    num_inference_steps=30,
    guidance_scale=7.0,
).images[0]

image.save("Leaves-v4.png")
image

# %%
prompt = "An image of the text 'Gifu AI Study Group' created by arranging leaves. The letters themselves are written with leaves."

image = pipe(
    prompt,
    num_inference_steps=30,
    guidance_scale=7.0,
).images[0]

image.save("Leaves-v5.png")
image

# %%
prompt = "A piece of art made by arranging pressed leaves to form English text 'Gifu AI Study Group'"

image = pipe(
    prompt,
    num_inference_steps=30,
    guidance_scale=7.0,
).images[0]

image.save("Leaves-v6.png")
image

# %%
prompt = "A piece of art made by arranging pressed leaves to form English text 'Gifu AI Study Group' with clear text."

image = pipe(
    prompt,
    num_inference_steps=30,
    guidance_scale=7.0,
).images[0]

image.save("Leaves-v7.png")
image
