# %% [markdown]
# <a href="https://colab.research.google.com/github/fukagai-takuya/gifu-ai/blob/main/gifu-ai-2025-12-21/FLUX1_schnell_Git_Clone_from_Fork_Diffusers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. 勉強会用に fork した diffusers のリポジトリを git clone し、ディレクトリを diffusers に変えてから、調査用に用意したブランチ investigate_flux.1_schnell にブランチを変えます。このブランチは調査用のブレイクポイントが FluxTransformer2DModel.forward の先頭にセットされています。

# %%
# !git clone https://github.com/fukagai-takuya/diffusers.git
# %cd diffusers
# !git checkout investigate_flux.1_schnell

# %% [markdown]
# 2. git clone した diffusers のソースコードを優先して参照するようにします

# %%
import sys
sys.path.insert(0, "/content/diffusers/src")

# %% [markdown]
# 3. git clone した diffusers のソースコードが優先して参照されることを確認します

# %%
import diffusers
print(diffusers.__file__)

# %% [markdown]
# 4. diffusers を使用して FLUX.1 [schnell] を実行する際に必要なパッケージをインストールします

# %%
# !pip install torch torchvision torchaudio
# !pip install transformers accelerate safetensors
# !pip install sentencepiece protobuf einops

# %% [markdown]
# 5. pdb より高機能な Python デバッガ ipdb をインストールします。

# %%
# !pip install ipdb

# %% [markdown]
# 6. FLUX.1 [schnell] を使用した Pipeline を用意します

# %%
import torch
from diffusers import FluxPipeline

pipe = FluxPipeline.from_pretrained(
    "black-forest-labs/FLUX.1-schnell",
    torch_dtype=torch.float16
).to("cuda")

# %% [markdown]
# 7. FLUX.1 [schnell] を使用して画像を生成します

# %%
prompt = 'The phrase "Gifu AI Study Group" formed from small colorful geometric shapes.'

image = pipe(
    prompt,
    guidance_scale=0.0,
    num_inference_steps=4,
    max_sequence_length=256
).images[0]

image.save("Gifu-AI-study-group.png")
